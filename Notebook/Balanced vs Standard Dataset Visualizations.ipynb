# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spreads = {"CNN-BiLSTM (Electronics)": 0.62 - 0.62, "CNN-BiLSTM (Clothing,Shoes,Jewelry)": 0.58 - 0.64,
 "CNN - attention (Electronics)": 0.62 - 0.6, "CNN - attention (Clothing,Shoes,Jewelry)": 0.65 - 0.63}
x_values = list(spreads.keys())
print(x_values)
y_values = list(spreads.values())
# Out:
# ['CNN-BiLSTM (Electronics)', 'CNN-BiLSTM (Clothing,Shoes,Jewelry)', 'CNN - attention (Electronics)', 'CNN - attention (Clothing,Shoes,Jewelry)']

# %%
plt.barh(x_values, y_values)
#plt.xticks(rotation=90)
plt.xlabel("Improvement in F1 Score")
plt.ylabel("Models")
plt.title("F1 Score Differentials")
plt.show()
